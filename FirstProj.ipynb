# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmh7/MyLearnings/blob/main/FirstProj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# Simula datos raw. En un caso real, podrías cargar esto desde un archivo o una API.
raw_data = """index,letter,state
1,a,true
2,b,false
3,c,true
4,d,false
5,e,true
"""

# Usa io.StringIO para tratar el string como un archivo
data_io = io.StringIO(raw_data)

# Lee los datos en un DataFrame de pandas
df = pd.read_csv(data_io)

# Muestra las primeras 5 filas del DataFrame
display(df.head())
# Out:
#    index letter  state
# 0      1      a   True
# 1      2      b  False
# 2      3      c   True
# 3      4      d  False
# 4      5      e   True
